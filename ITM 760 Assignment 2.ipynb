# %%
# import libraries
import pandas as pd
import numpy as np
import random 
from apyori import apriori

# %%
orders = pd.read_csv('orders.csv')

# %%
orders.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
products = pd.read_csv('products.csv')

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
orders.shape
# Out:
# (32434489, 4)

# %%
products.shape
# Out:
# (49688, 4)

# %%
# merge both datasets into one
product_orders = pd.merge(products, orders, on='product_id').sort_values(by='order_id')
product_orders.shape
# Out:
# (32434489, 7)

# %%
product_orders.tail()
# Out:
#           product_id                               product_name  aisle_id  \
# 12835237       21162   Organic Mixed Berry Yogurt & Fruit Snack        92
# 15933432       24852                                     Banana        24
# 10779617       18176    Organic Strawberry Yogurt & Fruit Snack        92
# 25491843       39678  Free & Clear Natural Dishwasher Detergent        74
# 29338254       45309            Purple Carrot & blueberry Puffs        92
#
#           department_id  order_id  add_to_cart_order  reordered
# 12835237             18   3421083                  3          0
# 15933432              4   3421083                  9          1
# 10779617             18   3421083                  4          1
# 25491843             17   3421083                  6          1
# 29338254             18   3421083                  2          0

# %%
# Reservoir sampling (used a set for faster runtime)
product_order_ids = set(product_orders['order_id'])
order_product_names = []

while len(order_product_names) < 10000:
    random_order_id = random.choice(list(product_order_ids))
    if random_order_id in product_order_ids:
        order = product_orders.loc[product_orders['order_id'] == random_order_id, 'product_name'].tolist()
        order_product_names.append(order)
        product_order_ids.remove(random_order_id)

# %%
print(order_product_names)
# Out:
# [['Organic Creamy Chocolate Fudge Nutritional Shake', 'Organic Sweet Vanilla Bean Nutrition Complete Protein Shake', 'Frozen Greek Yogurt Bars Blueberry'], ['Lowfat Cottage Cheese', 'Bananas', 'Wakame, Pacific, Silver Grade, Ready-to-Use', 'Qualita Rossa Ground Coffee', 'Fat Free Milk', 'Penne Rigate #41 Pasta', 'Greek Yogurt Style Nonfat Yogurt', 'Cheese Alternative, American Style, Slices', 'Cage Free Large White Eggs', 'Parsley, Italian (Flat), New England Grown', 'Kelp, Wild Atlantic Kombu', 'Organic Tomato Sauce', 'Sauerkraut Salad, Arame (Sea Vegetable) & Ginger', 'Spaghetti  No 12', 'Premium Green Tea Bags', 'Organic Watercress', 'Dandruff Relief Shampoo'], ['Chunk Light Tuna In Water', 'Intense & Smoky French Roast Dark Roast Ground Coffee', 'Shredded Parmesan Cheese', 'Pepper Gournay Cheese', 'Traditional Chicken & Wild Rice Soup', 'Bathroom Tissue Softness & Strength, Double Rolls', 'Romaine Hearts', 'Roma Tomato', 'Garlic & Fine Herbs Gournay Cheese', 'Multi Grain Crispbread', 'Chunky Grilled Chicken & Sausage Gumbo Soup', 'Organic Grade A Large Brown Eggs', 'Iceberg Garden Salad Blend', 'Chicken Breast Tenders', 'Traditional Crumbled Feta Cheese', 'No Sugar Added Apple Sauce', 'Home Style Asiago Caesar Dressing', 'Creamy Chicken & Dumplings Soup', 'Traditional Italian-Style Wedding Soup', 'Uncured Hickory Smoked Sunday Bacon'], ['Spring Water', 'Organic Red Lentil Penne', 'Unsweetened Almondmilk', 'Organic Baby Spinach', 'Flax Plus Raisin Bran Cereal'], ['Gallon Storage Slider Bags', 'Deli Fresh Smoked Turkey Breast', '
ordered_statistics=[OrderedStatistic(items_base=frozenset({'1% Lowfat Milk'}), items_add=frozenset({'Banana'}), confidence=0.37735849056603776, lift=2.4744819053510674)]), RelationRecord(items=frozenset({'100% Raw Coconut Water', 'Bag of Organic Bananas'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'100% Raw Coconut Water'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.24390243902439024, lift=2.14325517596125)]), RelationRecord(items=frozenset({'Banana', '100% Whole Wheat Bread'}), support=0.0043, ordered_statistics=[OrderedStatistic(items_base=frozenset({'100% Whole Wheat Bread'}), items_add=frozenset({'Banana'}), confidence=0.2275132275132275, lift=1.4918900164801803)]), RelationRecord(items=frozenset({'Organic Strawberries', '2% Reduced Fat DHA Omega-3 Reduced Fat Milk'}), support=0.0012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2% Reduced Fat DHA Omega-3 Reduced Fat Milk'}), items_add=frozenset({'Organic Strawberries'}), confidence=0.3428571428571428, lift=4.019427231619494)]), RelationRecord(items=frozenset({'2% Reduced Fat Milk', 'Banana'}), support=0.0035, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2% Reduced Fat Milk'}), items_add=frozenset({'Banana'}), confidence=0.2966101694915254, lift=1.944984717977216)]), RelationRecord(items=frozenset({'2% Reduced Fat Organic Milk', 'Banana'}), support=0.0016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2% Reduced Fat Organic Milk'}), items_add=frozenset({'Banana'}), confidence=0.29090909090909095, lift=1.9076005961251865)]), RelationRecord(items=frozenset({'Banana', '85% Lean Ground Beef'}), support=0.0011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'85% Lean Ground Beef'}), items_add=frozenset({'Banana'}), confidence=0.2619047619047619, lift=1.717408274785324)]), RelationRecord(items=frozenset({'Bag of Organic Bananas', 'Aged White Cheddar Baked Rice & Corn Puffs Gluten Free Lunch Packs'}), support=0.001, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aged White Cheddar Baked Rice & Corn Puffs Gluten Free Lunch Packs'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.38461538461538464, lift=3.379748546708125)]), RelationRecord(items=frozenset({'Bag of Organic Bananas', 'Air Chilled Organic Boneless Skinless Chicken Breasts'}), support=0.0011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Air Chilled Organic Boneless Skinless Chicken Breasts'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.2037037037037037, lift=1.7900149710343032)]), RelationRecord(items=frozenset({'Almonds & Sea Salt in Dark Chocolate', 'Organic Strawberries'}), support=0.0012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Almonds & Sea Salt in Dark Chocolate'}), items_add=frozenset({'Organic Strawberries'}), confidence=0.3243243243243243, lift=3.802160894775197)]), RelationRecord(items=frozenset({'Bag of Organic Bananas', 'Apple Honeycrisp Organic'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Honeycrisp Organic'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.23346303501945526, lift=2.051520518624387)]), RelationRecord(items=frozenset({'Organic Strawberries', 'Apple Honeycrisp Organic'}), support=0.0055, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Honeycrisp Organic'}), items_add=frozenset({'Organic Strawberries'}), confidence=0.2140077821011673, lift=2.5088837292047748)]), RelationRecord(items=frozenset({'Apple Juice', 'Banana'}), support=0.0013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Juice'}), i ...

# %%
# extract the association rule + the corresponding confidence and append to rules list
rules_list = []

for item in association_results:
    rules = item[0]
    pairs = [x for x in rules]
    confidence = item[2][0][2]
    rules_list.append([pairs[0] + ' ' + '->' + ' ' + pairs[1],confidence])

# %%
# convert rules list to a dataframe sorted by confidence in descending order and list first 50 rows
rules_df = pd.DataFrame(rules_list,columns=['Association Rule', 'Confidence']).sort_values(by='Confidence', ascending=False)
rules_df.head(50)
